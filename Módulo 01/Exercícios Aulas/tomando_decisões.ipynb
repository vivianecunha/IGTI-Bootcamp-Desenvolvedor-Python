# %% [markdown]
# **Como podemos fazer com que o nosso programa consiga modificar o fluxo de execução?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **O caso do if**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#exemplo
print('Execução antes do if...')

numero=float(input('Entre com um número: '))
if numero%2==0:
  print('Esse é um número par.')
  
print('Execução após o if...')
# Out:
# Execução antes do if...
# Entre com um número: 5
# Execução após o if...

# %%
print('Execução antes do if...')

numero=float(input('Entre com um número: '))
if numero>0:
  print('Esse numero é positivo.')
  
print('Execução após o if...')
# Out:
# Execução antes do if...
# Entre com um número: -4
# Execução após o if...

# %%
i = 10
if (i > 15): 
   print ("10 é maior que 15") 
print ("Continuando o programa ...")
# Out:
# Continuando o programa ...

# %% [markdown]
# # **O caso if-else**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#exemplo
print('Execução antes do if...\n')

numero=float(input('Entre com um número: '))
if numero%2==0:
  print('Esse é um número par.\n')
else:
  print('Esse é um número impar.\n')
  
print('Execução após o if...')
# Out:
# Execução antes do if...
#
# Entre com um número: 11
# Esse é um número impar.
#
# Execução após o if...

# %%
i = 20; 
if (i < 15): 
    print ("i é menor que 15") 
    print ("Execução do if ....") 
else: 
    print ("i é maior que 15") 
    print ("Execução do else") 
print ("Continuando o programa......")
# Out:
# i é maior que 15
# Execução do else
# Continuando o programa......

# %%
#encontrando o maior valor entre dois números inteiros digitados
x=int(input('Digite o primeiro número:'))
y=int(input('Digite o segundo número:'))
if (x>y):
  print('O primeiro valor (%2d) é maior que o segundo valor (%2d)'%(x,y))
else:
  print('O primeiro valor (%2d) é menor que o segundo valor (%2d)'%(x,y))
# Out:
# Digite o primeiro número:1
# Digite o segundo número:10
# O primeiro valor ( 1) é menor que o segundo valor (10)

# %% [markdown]
# **If com condições mais "elaboradas"**

# %%
#if com condicional or
altura= int(input ("Entre com a sua altura (em centimetros): "))
if (altura<150) or (altura >180):
  print("Você não pode brincar ")
else:
  print("Você pode brincar")
# Out:
# Entre com a sua altura (em centimetros): 170
# Você pode brincar

# %%
#adivinhado resultados da divisão
numerador=float(input('Entre com o numerador: '))
denominador= float(input('Entre com o denominador: '))

chute=float(input('Entre com o seu chute para o resultado: '))

resultado=numerador/denominador

maior=abs(resultado)

#verifica se o chute é até 1/10 do real
if abs((chute - resultado)/maior) <=0.1:
  print("Seu Chute está correto. Parabéns!!")
else:
  print("Que pena, você errou. O valor correto é {}".format(resultado))
# Out:
# Entre com o numerador: 20
# Entre com o denominador: 10
# Entre com o seu chute para o resultado: 2.2
# Que pena, você errou. O valor correto é 2.0

# %% [markdown]
# # **if aninhados**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = 10
if (i == 10): 
    #  Primeiro if
    if (i < 15): 
        print ("i é maior que 15") 
    # O if aninhado só é executado se o anterior for executado
    if (i < 12): 
        print ("i também é menor que 12") 
    else: 
        print ("i é maior que 15")
print('Continua o programa....')
# Out:
# i é maior que 15
# i também é menor que 12
# Continua o programa....

# %%
x = float(input('Entre com um primeiro número: '))
y = float(input('Entre com um segundo número: '))

print('(1) - Soma os dois números')
print('(2) - Subtrai os dois números')
print('(3) - Multiplica os dois números')
print('(4) - Divide os dois números')

escolha=int(input('Escolha uma das opções: '))

print('O resultado é: ', end="")

if escolha==1:
  print(x+y)
else:
  if (escolha==2):
    print(x-y)
  else:
    if(escolha==3):
      print(x*y)
    else:
      if(escolha==4):
        print(x/y)
      else:
        print('Opção inválida')
# Out:
# Entre com um primeiro número: 10
# Entre com um segundo número: 20
# (1) - Soma os dois números
# (2) - Subtrai os dois números
# (3) - Multiplica os dois números
# (4) - Divide os dois números
# Escolha uma das opções: 6
# O resultado é: Opção inválida

# %%
#outras condicionais aninhadas
x=5
y=10
if x == y:
    print('x e y são iguais')
else:
    if x < y:
        print('x é menor do que y')
    else:
        print('x é maior do que y')
# Out:
# x é menor do que y

# %% [markdown]
# # **if-elif-else**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = 15
if (i == 10): 
    print ("i é igual a 10") 
elif (i == 15): 
    print ("i é igual a 15") 
elif (i == 20): 
    print ("i é igual a 20") 
else: 
    print ("i não está nas condições")
print('..........')
# Out:
# i é igual a 15
# ..........

# %%
x = float(input('Entre com um primeiro número: '))
y = float(input('Entre com um segundo número: '))

print('(1) - Soma os dois números')
print('(2) - Subtrai os dois números')
print('(3) - Multiplica os dois números')
print('(4) - Divide os dois números')

escolha=int(input('Escolha uma das opções: '))

print('O resultado é: ', end="")

if escolha==1:
  print(x+y)
elif (escolha==2):
  print(x-y)
elif (escolha==3):
  print(x*y)
elif (escolha==4):
  print(x/y)
else:
  print('Opção inválida')
# Out:
# Entre com um primeiro número: 10
# Entre com um segundo número: 30
# (1) - Soma os dois números
# (2) - Subtrai os dois números
# (3) - Multiplica os dois números
# (4) - Divide os dois números
# Escolha uma das opções: 5
# O resultado é: Opção inválida

# %% [markdown]
# **Encontrando o maior entre 3 números**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int ( input ( " Entre com o primeiro número inteiro : " ))
y = int ( input ( " Entre com o segundo número inteiro : " ))
z = int ( input ( " Entre com o terceiro número inteiro : " ))
if y > x:
  if z > y:
    print (z , " é o maior número. " )
  else:
    print (y , " é o maior número. " )
else:
  if z > x:
    print (z , " é o maior número. " )
  else:
    print (x , " é o maior número. " )
print ( " Fim. " )
# Out:
#  Entre com o primeiro número inteiro : 3
#  Entre com o segundo número inteiro : 2
#  Entre com o terceiro número inteiro : 1
# 3  é o maior número.
#  Fim.

# %% [markdown]
# **Forma mais "inteligente"**

# %%
x = int ( input ( " Entre com o primeiro número inteiro : " ))
y = int ( input ( " Entre com o segundo número inteiro : " ))
z = int ( input ( " Entre com o terceiro número inteiro : " ))
# Primeiro chute
maior_numero = x
if y > maior_numero :
 # ajusta o primeiro chute
  maior_numero = y
if z > maior_numero :
 # ajusta o segundo chute
  maior_numero = z
print ( maior_numero , " é o maior número. " )
print ( " Fim. " )
# Out:
#  Entre com o primeiro número inteiro : 1
#  Entre com o segundo número inteiro : 2
#  Entre com o terceiro número inteiro : 3
# 3  é o maior número.
#  Fim.

# %% [markdown]
# **Trabalhando com exceções**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exceções vs Erros de Sintaxe**

# %%
#erro devido a sintaxe
print( 0 / 0 ))
# Out:
#   File "<ipython-input-54-cd327d02030b>", line 2
#     print( 0 / 0 ))
#                   ^
# SyntaxError: invalid syntax

# %%
#erro de exceção
print( 0 / 0 )
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-55-7d2eab1be1ca> in <module>()
#       1 #erro de exceção
# ----> 2 print( 0 / 0 )
#
# ZeroDivisionError: division by zero

# %%
#gerando uma exceção
x = 4
if x > 5:
    raise Exception('x não deve ser maior do que 5. O valor de x digitado foi: {}'.format(x))
print('....')
# Out:
# ....

# %%
#lidando com erros  - verificando se um número é divisível por outro

numerador=int(input("Entre com o numerador: "))
denominador=int(input("Entre com o denominador: "))

if numerador % denominador ==0:
  print("O numerador é divisível pelo denominador.")
else:
  print("A divisão não é inteira.")
# Out:
# Entre com o numerador: 10
# Entre com o denominador: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-61-0cc2df20c6e3> in <module>()
#       4 denominador=int(input("Entre com o denominador: "))
#       5
# ----> 6 if numerador % denominador ==0:
#       7   print("O numerador é divisível pelo denominador.")
#       8 else:
#
# ZeroDivisionError: integer division or modulo by zero

# %%
#exemplo de adivinhação com exceções
try:
  numerador=int(input("Entre com o numerador: "))
except ValueError: #captura apenas exceções do tipo ValueErrors
  print("Você não entrou com um número inteiro.")
  exit(0)

try:
  denominador=int(input("Entre com o denominador: "))
except:  #lida com qualquer tipo de erro
  print("Você não entrou um número inteiro.")
  exit(0)

try:
  if numerador % denominador ==0:
    print("O numerador é divisível pelo denominador.")
  else:
    print("A divisão não é inteira.")
except ZeroDivisionError:  #captura divisões por zero
  print("Denominador não pode ser zero.")
# Out:
# Entre com o numerador: 10
# Entre com o denominador: 0
# Denominador não pode ser zero.

# %% [markdown]
# **Quando utilizar em seu código?**

# %%
raise KeyError('Isso é  o que ocorre')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-564a18f22637> in <module>()
# ----> 1 raise KeyError('Isso é  o que ocorre')
#
# KeyError: 'Isso é  o que ocorre'

# %%
idades = {'Tulio': 30, 'Maria': 28, 'Antônio': 33}
pessoa = input('Quero saber a idade de: ')
idade = idades.get(pessoa)

if idade:
    print(f'{pessoa} tem {idade} anos de idade.')
else:
    print(f"{pessoa} com idade desconhecida.")
# Out:
# Quero saber a idade de: Gilberto
# Gilberto com idade desconhecida.

# %%
idades = {'Tulio': 30, 'Maria': 28, 'Antônio': 33}
pessoa = input('Quero saber a idade de: ')
idade = idades.get(pessoa)
try:
    print(f'{pessoa} tem {idades[pessoa]} anos de idade.')
except KeyError:
    print(f"{pessoa} com idade desconhecida.")
# Out:
# Quero saber a idade de: Gilberto
# Gilberto com idade desconhecida.
